# %% [markdown]
# # EDA
# ## Vivienda en Madrid

# %%
import pandas as pd
from utils import funciones as f

pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('.\data\houses_Madrid.csv', index_col='Unnamed: 0')
data = data.sort_index(axis= 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21742 entries, 0 to 21741
# Data columns (total 57 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   are_pets_allowed              0 non-null      float64
#  1   built_year                    10000 non-null  float64
#  2   buy_price                     21742 non-null  int64
#  3   buy_price_by_area             21742 non-null  int64
#  4   door                          0 non-null      float64
#  5   energy_certificate            21742 non-null  object
#  6   floor                         19135 non-null  object
#  7   has_ac                        11211 non-null  object
#  8   has_balcony                   3321 non-null   object
#  9   has_central_heating           13608 non-null  object
#  10  has_fitted_wardrobes          13399 non-null  object
#  11  has_garden                    1556 non-null   object
#  12  has_green_zones               4057 non-null   object
#  13  has_individual_heating        13608 non-null  object
#  14  has_lift                      19356 non-null  object
#  15  has_parking                   21742 non-null  bool
#  16  has_pool                      5171 non-null   object
#  17  has_private_parking           0 non-null      float64
#  18  has_public_parking            0 non-null      float64
#  19  has_storage_room              7698 non-null   object
#  20  has_terrace                   9548 non-null   object
#  21  house_type_id                 21351 non-null  object
#  22  id                            21742 non-null  int64
#  23  is_accessible                 4074 non-null   object
#  24  is_buy_price_known            21742 non-null  bool
#  25  is_exact_address_hidden       21742 non-null  bool
#  26  is_exterior                   18699 non-null  object
#  27  is_floor_under                20572 non-null  object
#  28  is_furnished                  0 non-null      float64
#  29  is_kitchen_equipped           0 non-null      float64
#  30  is_new_development            20750 non-null  object
#  31  is_orientation_east           11358 non-null  object
#  32  is_orientation_north          11358 non-null  object
#  33  is_orientation_south          11358 non-null  object
#  34  is_orientation_west           11358 non-null  object
#  35  is_parking_included_in_price  7719 non-null   object
#  36  is_renewal_needed             21742 non-null  bool
#  37  is_rent_price_known           21742 non-null  bool
#  38  latitude                      0 non-null      float64
#  39  longitude                     0 non-null      float64
#  40  n_bathrooms                   21726 non-null  float64
#  41  n_floors                      1437 non-null   float64
#  42  n_rooms                       21742 non-null  int64
#  43  neighborhood_id               21742 non-null  object
#  44  operation                     21742 non-null  object
#  45  parking_price                 7719 non-null   float64
#  46  portal                        0 non-null      float64
#  47  raw_address                   16277 non-null  object
#  48  rent_price                    21742 non-null  int64
#  49  rent_price_by_area            0 non-null      float64
#  50  sq_mt_allotment               1432 non-null   float64
#  51  sq_mt_built                   21616 non-null  float64
#  52  sq_mt_useful                  8228 non-null   float64
#  53  street_name                   15837 non-null  object
#  54  street_number                 6300 non-null   object
#  55  subtitle                      21742 non-null  object
#  56  title                         21742 non-null  object
# dtypes: bool(5), float64(17), int64(5), object(30)
# memory usage: 8.9+ MB

# %%
data.describe(include = 'all').round()
# Out:
#         are_pets_allowed  built_year  buy_price  buy_price_by_area  door  \
# count                0.0     10000.0    21742.0            21742.0   0.0
# unique               NaN         NaN        NaN                NaN   NaN
# top                  NaN         NaN        NaN                NaN   NaN
# freq                 NaN         NaN        NaN                NaN   NaN
# mean                 NaN      1970.0   653736.0             4021.0   NaN
# std                  NaN        69.0   782082.0             1908.0   NaN
# min                  NaN      1723.0    36000.0              447.0   NaN
# 25%                  NaN      1957.0   198000.0             2551.0   NaN
# 50%                  NaN      1970.0   375000.0             3720.0   NaN
# 75%                  NaN      1994.0   763600.0             5000.0   NaN
# max                  NaN      8170.0  8800000.0            18889.0   NaN
#
#        energy_certificate  floor has_ac has_balcony has_central_heating  \
# count               21742  19135  11211        3321               13608
# unique                 10     19      1           1                   2
# top            en trámite      1   True        True               False
# freq                10937   4440  11211        3321                9516
# mean                  NaN    NaN    NaN         NaN                 NaN
# std                   NaN    NaN    NaN         NaN                 NaN
# min                   NaN    NaN    NaN         NaN                 NaN
# 25%                   NaN    NaN    NaN         NaN                 NaN
# 50%                   NaN    NaN    NaN         NaN                 NaN
# 75%                   NaN    NaN    NaN         NaN                 NaN
# max                   NaN    NaN    NaN         NaN                 NaN
#
#        has_fitted_wardrobes has_garden has_green_zones has_individual_heating  \
# count                 13399       1556            4057                  13608
# unique                    1          1               1                      2
# top                    True       True            True                   True
# freq                  13399       1556            4057                   9516
# mean                    NaN        NaN             NaN                    NaN
# std                     NaN        NaN             NaN                    NaN
# min                     NaN        NaN             NaN                    NaN
# 25%                     NaN        NaN             NaN                    NaN
# 50%                     NaN        NaN             NaN                    NaN
# 75%                     NaN        NaN             NaN                    NaN
# max                     NaN        NaN             NaN                    NaN
#
#        has_lift has_parking has_pool  has_private_parking  has_public_parking  \
# count     19356       21742     5171                  0.0                 0.0
# unique        2           2        1                  NaN                 NaN
# top        True       False     True                  NaN                 NaN
# freq      14895       14023     5171                  NaN                 NaN
# mean        NaN         NaN      NaN                  NaN                 NaN
# std         NaN         NaN      NaN                  NaN                 NaN
# min         NaN         NaN      NaN                  NaN                 NaN
# 25%         NaN         NaN      NaN                  NaN                 NaN
# 50%         NaN         NaN      NaN                  NaN                 NaN
# 75%         NaN         NaN      NaN                  NaN                 NaN
# max         NaN         NaN      NaN                  NaN                 NaN
#
#        has_storage_room has_terrace       house_type_id       id  \
# count              7698        9548               21351  21742.0
# unique                1           1                   4      NaN
# top                True        True  HouseType 1: Pisos      NaN
# freq               7698        9548               17705      NaN
# mean                NaN         NaN                 NaN  10872.0
# std                 NaN         NaN                 NaN   6277.0
# min                 NaN         NaN                 NaN      1.0
# 25%                 NaN         NaN                 NaN   5436.0
# 50%                 NaN         NaN                 NaN  10872.0
# 75%                 NaN         NaN                 NaN  16307.0
# max                 NaN         NaN                 NaN  21742.0
#
#        is_accessible is_buy_price_known is_exact_address_hidden is_exterior  \
# count           4074              21742                   21742       18699
# unique             1                  1                       2           2
# top             True               True                    True        True
# freq            4074              21742                   15002       16922
# mean             NaN                NaN                     NaN         NaN
# std              NaN                NaN                     NaN         NaN
# min              NaN                NaN                     NaN         NaN
# 25%              NaN                NaN                     NaN         NaN
# 50%              NaN                NaN                     NaN         NaN
# 75%              NaN                NaN                     NaN         NaN
# max              NaN                NaN                     NaN         NaN
#
#        is_floor_under  is_furnished  is_kitchen_equipped is_new_development  \
# count           20572           0.0                  0.0              20750
# unique              2           NaN                  NaN                  2
# top             False           NaN                  NaN              False
# freq            18033           NaN                  NaN              19281
# mean              NaN           NaN                  NaN                NaN
# std               NaN           NaN                  NaN                NaN
# min               NaN           NaN                  NaN                NaN
# 25%               NaN           NaN                  NaN                NaN
# 50%               NaN           NaN                  NaN                NaN
# 75%               NaN           NaN                  NaN                NaN
# max               NaN           NaN                  NaN                NaN
#
#        is_orientation_east is_orientation_north is_orientation_south  \
# count                11358                11358                11358
# unique                   2                    2                    2
# top                  False                False                 True
# freq                  6302                 8567                 5823
# mean                   NaN                  NaN                  NaN
# std                    NaN                  NaN                  NaN
# min                    NaN                  NaN                  NaN
# 25%                    NaN                  NaN                  NaN
# 50%                    NaN                  NaN                  NaN
# 75%                    NaN                  NaN                  NaN
# max                    NaN                  NaN                  NaN
#
#        is_orientation_west is_parking_included_in_price is_renewal_needed  \
# count                11358                         7719             21742
# unique                   2                            2                 2
# top                  False                         True             False
# freq                  7287                         7115             17747
# mean                   NaN                          NaN               NaN
# std                    NaN                          NaN               NaN
# min                    NaN                          NaN               NaN
# 25%                    NaN                          NaN               NaN
# 50%                    NaN                          NaN               NaN
# 75%                    NaN                          NaN               NaN
# max                    NaN                          NaN               NaN
#
#        is_rent_price_known  latitude  longitude  n_bathrooms  n_floors  \
# count                21742       0.0        0.0      21726.0    1437.0
# unique                   1       NaN        NaN          NaN       NaN
# top                  False       NaN        NaN          NaN       NaN
# freq                 21742       NaN        NaN          NaN       NaN
# mean                   NaN       NaN        NaN          2.0       3.0
# std                    NaN       NaN        NaN          1.0       1.0
# min                    NaN       NaN        NaN          1.0       1.0
# 25%                    NaN       NaN        NaN          1.0       2.0
# 50%                    NaN       NaN        NaN          2.0       3.0
# 75%                    NaN       NaN        NaN          2.0       4.0
# max                    NaN       NaN        NaN         16.0       7.0
#
#         n_rooms                                    neighborhood_id operation  \
# count   21742.0                                              21742     21742
# unique      NaN                                                126         1
# top         NaN  Neighborhood 23: Malasaña-Universidad (5196.25...      sale
# freq        NaN                                                485     21742
# mean        3.0                                                NaN       NaN
# std         2.0                                                NaN       NaN
# min         0.0                                                NaN       NaN
# 25%         2.0                                                NaN       NaN
# 50%         3.0                                                NaN       NaN
# 75%         4.0                                                NaN       NaN
# max        24.0                                                NaN       NaN
#
#         parking_price  portal             raw_address  rent_price  \
# count          7719.0     0.0                   16277     21742.0
# unique            NaN     NaN                    9666         NaN
# top               NaN     NaN  Paseo de la Castellana         NaN
# freq              NaN     NaN                      94         NaN
# mean           2658.0     NaN                     NaN    -59170.0
# std           13361.0     NaN                     NaN    917116.0
# min               0.0     NaN                     NaN -34590276.0
# 25%               0.0     NaN                     NaN       725.0
# 50%               0.0     NaN                     NaN      1116.0
# 75%               0.0     NaN                     NaN      1687.0
# max          600000.0     NaN                     NaN      2517.0
#
#         rent_price_by_area  sq_mt_allotment  sq_mt_built  sq_mt_useful  \
# count                  0.0           1432.0      21616.0        8228.0
# unique                 NaN              NaN          NaN           NaN
# top                    NaN              NaN          NaN           NaN
# freq                   NaN              NaN          NaN           NaN
# mean                   NaN            242.0        147.0         103.0
# std                    NaN            247.0        134.0          88.0
# min                    NaN              1.0         13.0           1.0
# 25%                    NaN              2.0         70.0          59.0
# 50%                    NaN            232.0        100.0          79.0
# 75%                    NaN            354.0        162.0         113.0
# max                    NaN            997.0        999.0         998.0
#
#                    street_name street_number           subtitle  \
# count                    15837          6300              21742
# unique                    6177           420                146
# top     Paseo de la Castellana             4  Chamartín, Madrid
# freq                       116           210                851
# mean                       NaN           NaN                NaN
# std                        NaN           NaN                NaN
# min                        NaN           NaN                NaN
# 25%                        NaN           NaN                NaN
# 50%                        NaN           NaN                NaN
# 75%                        NaN           NaN                NaN
# max                        NaN           NaN                NaN
#
#                            title
# count                      21742
# unique                     10736
# top     Piso en venta en El Viso
# freq                         193
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN

# %%
df = f.nombre_columnas(data)

# %%
f.cardinalidad(df)
# Out:
#                variable tipo_dato  cantidad_de_nulos  \
# 0    annio_construccion   float64              11742
# 1          precio_venta     int64                  0
# 2   precio_venta_por_m2     int64                  0
# 3                   cee    object                  0
# 4                  piso    object               2607
# 5                balcon    object              18421
# 6   armarios_empotrados    object               8343
# 7                jardin    object              20186
# 8          zonas_verdes    object              17685
# 9       estacionamiento      bool                  0
# 10               pileta    object              16571
# 11             trastero    object              14044
# 12              terraza    object              12194
# 13        tipo_inmueble    object                391
# 14            accesible    object              17668
# 15             exterior    object               3043
# 16                 bajo    object               1170
# 17     necesita_reforma      bool                  0
# 18               bannos   float64                 16
# 19         habitaciones     int64                  0
# 20     metros_cuadrados   float64                126
# 21            ubicacion    object                  0
#
#                                        valores_unicos  cardinalidad  \
# 0   [1960.0, nan, 1955.0, 2003.0, 1981.0, 1950.0, ...           155
# 1   [85000, 129900, 144247, 109900, 260000, 195000...          2403
# 2   [1328, 1856, 1535, 1717, 2407, 1548, 1583, 158...          5643
# 3   [D, en trámite, no indicado, F, E, inmueble ex...            10
# 4   [3, 4, 1, Bajo, 2, nan, 7, 6, Semi-sótano, 5, ...            19
# 5                                         [nan, True]             1
# 6                                         [nan, True]             1
# 7                                         [nan, True]             1
# 8                                         [nan, True]             1
# 9                                       [False, True]             2
# 10                                        [nan, True]             1
# 11                                        [nan, True]             1
# 12                                        [nan, True]             1
# 13  [HouseType 1: Pisos, HouseType 4: Dúplex, nan,...             4
# 14                                        [nan, True]             1
# 15                                 [True, nan, False]             2
# 16                                 [False, True, nan]             2
# 17                                      [False, True]             2
# 18  [1.0, 2.0, 3.0, 4.0, 6.0, nan, 5.0, 14.0, 7.0,...            16
# 19  [2, 3, 4, 5, 1, 0, 8, 6, 9, 7, 12, 10, 11, 16,...            19
# 20  [64.0, 70.0, 94.0, 108.0, 126.0, 120.0, 125.0,...           678
# 21  [San Cristóbal, Madrid, Los Ángeles, Madrid, S...           146
#
#     porcentaje_cardinalidad tipo_variable
# 0                  0.712906      discreta
# 1                 11.052341      continua
# 2                 25.954374      continua
# 3                  0.045994       ordinal
# 4                  0.087388       ordinal
# 5                  0.004599       nominal
# 6                  0.004599       nominal
# 7                  0.004599       nominal
# 8                  0.004599       nominal
# 9                  0.009199       nominal
# 10                 0.004599       nominal
# 11                 0.004599       nominal
# 12                 0.004599       nominal
# 13                 0.018398       nominal
# 14                 0.004599       nominal
# 15                 0.009199       nominal
# 16                 0.009199       nominal
# 17                 0.009199       nominal
# 18                 0.073590      discreta
# 19                 0.087388      discreta
# 20                 3.118388      continua
# 21                 0.671511       nominal

# %% [markdown]
# ## Analisis Univariante

# %% [markdown]
# ##### Variables Cuantitativas

# %%
df_cuant = df.select_dtypes(include = 'number')
df_cuant.describe().round()
# Out:
#        annio_construccion  precio_venta  precio_venta_por_m2   bannos  \
# count             10000.0       21742.0              21742.0  21726.0
# mean               1970.0      653736.0               4021.0      2.0
# std                  69.0      782082.0               1908.0      1.0
# min                1723.0       36000.0                447.0      1.0
# 25%                1957.0      198000.0               2551.0      1.0
# 50%                1970.0      375000.0               3720.0      2.0
# 75%                1994.0      763600.0               5000.0      2.0
# max                8170.0     8800000.0              18889.0     16.0
#
#        habitaciones  metros_cuadrados
# count       21742.0           21616.0
# mean            3.0             147.0
# std             2.0             134.0
# min             0.0              13.0
# 25%             2.0              70.0
# 50%             3.0             100.0
# 75%             4.0             162.0
# max            24.0             999.0

# %%
f.graficos_variables_cuant(df_cuant)
# Out:
# ------------------------------------------------------------
# VARIABLE: annio_construccion
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data[columna], orient='h', palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:77: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data[columna], rug = True, palette='husl' , bins = 30)
# count    10000.0
# mean      1970.0
# std         69.0
# min       1723.0
# 25%       1957.0
# 50%       1970.0
# 75%       1994.0
# max       8170.0
# Name: annio_construccion, dtype: float64
# ------------------------------------------------------------
# ------------------------------------------------------------
# VARIABLE: precio_venta
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data[columna], orient='h', palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:77: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data[columna], rug = True, palette='husl' , bins = 30)
# count      21742.0
# mean      653736.0
# std       782082.0
# min        36000.0
# 25%       198000.0
# 50%       375000.0
# 75%       763600.0
# max      8800000.0
# Name: precio_venta, dtype: float64
# ------------------------------------------------------------
# ------------------------------------------------------------
# VARIABLE: precio_venta_por_m2
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data[columna], orient='h', palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:77: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data[columna], rug = True, palette='husl' , bins = 30)
# count    21742.0
# mean      4021.0
# std       1908.0
# min        447.0
# 25%       2551.0
# 50%       3720.0
# 75%       5000.0
# max      18889.0
# Name: precio_venta_por_m2, dtype: float64
# ------------------------------------------------------------
# ------------------------------------------------------------
# VARIABLE: bannos
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data[columna], orient='h', palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:77: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data[columna], rug = True, palette='husl' , bins = 30)
# count    21726.0
# mean         2.0
# std          1.0
# min          1.0
# 25%          1.0
# 50%          2.0
# 75%          2.0
# max         16.0
# Name: bannos, dtype: float64
# ------------------------------------------------------------
# ------------------------------------------------------------
# VARIABLE: habitaciones
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data[columna], orient='h', palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:77: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data[columna], rug = True, palette='husl' , bins = 30)
# count    21742.0
# mean         3.0
# std          2.0
# min          0.0
# 25%          2.0
# 50%          3.0
# 75%          4.0
# max         24.0
# Name: habitaciones, dtype: float64
# ------------------------------------------------------------
# ------------------------------------------------------------
# VARIABLE: metros_cuadrados
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data[columna], orient='h', palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:77: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data[columna], rug = True, palette='husl' , bins = 30)
# count    21616.0
# mean       147.0
# std        134.0
# min         13.0
# 25%         70.0
# 50%        100.0
# 75%        162.0
# max        999.0
# Name: metros_cuadrados, dtype: float64
# ------------------------------------------------------------

# %% [markdown]
# ##### Variables Cualitativas

# %%
df_cual = df.select_dtypes(exclude= 'number')

# %%
f.graficos_variables_cualit(df_cual)
# Out:
# ----------------------------------------------------------------------------------------------------
# VARIABLE: cee
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data= data.sort_values(by=columna), x= columna, palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data[columna].sort_values().unique(), rotation=90)
# cee
# en trámite         10937
# no indicado         3669
# E                   2701
# D                   1121
# G                    894
# F                    674
# A                    618
# C                    580
# B                    452
# inmueble exento       96
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: piso
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data= data.sort_values(by=columna), x= columna, palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data[columna].sort_values().unique(), rotation=90)
# piso
# 1                       4440
# 2                       3546
# 3                       3001
# 4                       2323
# Bajo                    2144
# 5                       1310
# 6                        913
# 7                        556
# 8                        326
# Entreplanta exterior     236
# 9                        181
# Semi-sótano exterior      55
# Semi-sótano interior      36
# Entreplanta interior      32
# Sótano interior           23
# Sótano                     5
# Sótano exterior            4
# Entreplanta                3
# Semi-sótano                1
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: balcon
#
# No es necesario graficar porque tiene un solo valor dentro de la columna
# balcon
# True    3321
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: armarios_empotrados
#
# No es necesario graficar porque tiene un solo valor dentro de la columna
# armarios_empotrados
# True    13399
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: jardin
#
# No es necesario graficar porque tiene un solo valor dentro de la columna
# jardin
# True    1556
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: zonas_verdes
#
# No es necesario graficar porque tiene un solo valor dentro de la columna
# zonas_verdes
# True    4057
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: estacionamiento
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data= data.sort_values(by=columna), x= columna, palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data[columna].sort_values().unique(), rotation=90)
# estacionamiento
# False    14023
# True      7719
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: pileta
#
# No es necesario graficar porque tiene un solo valor dentro de la columna
# pileta
# True    5171
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: trastero
#
# No es necesario graficar porque tiene un solo valor dentro de la columna
# trastero
# True    7698
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: terraza
#
# No es necesario graficar porque tiene un solo valor dentro de la columna
# terraza
# True    9548
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: tipo_inmueble
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data= data.sort_values(by=columna), x= columna, palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data[columna].sort_values().unique(), rotation=90)
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data= data.sort_values(by=columna), x= columna, palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data[columna].sort_values().unique(), rotation=90)
# tipo_inmueble
# HouseType 1: Pisos            17705
# HouseType 2: Casa o chalet     1938
# HouseType 5: Áticos            1032
# HouseType 4: Dúplex             676
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: accesible
#
# No es necesario graficar porque tiene un solo valor dentro de la columna
# accesible
# True    4074
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: exterior
# exterior
# True     16922
# False     1777
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: bajo
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data= data.sort_values(by=columna), x= columna, palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data[columna].sort_values().unique(), rotation=90)
# bajo
# False    18033
# True      2539
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: necesita_reforma
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data= data.sort_values(by=columna), x= columna, palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data[columna].sort_values().unique(), rotation=90)
# necesita_reforma
# False    17747
# True      3995
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# VARIABLE: ubicacion
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data= data.sort_values(by=columna), x= columna, palette='husl')
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data[columna].sort_values().unique(), rotation=90)
# ubicacion
# Chamartín, Madrid                           851
# Moncloa, Madrid                             771
# Chamberí, Madrid                            583
# Centro, Madrid                              552
# Hortaleza, Madrid                           503
#                                            ...
# Barajas, Madrid                               7
# Campo de las Naciones-Corralejos, Madrid      6
# Casco Histórico de Barajas, Madrid            5
# Timón, Madrid                                 4
# Cuatro Vientos, Madrid                        2
# Name: count, Length: 146, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Limpieza de datos

# %%
'''ya guardé un csv con el dataframe ejecutado pero el utils esta la función con la que obtuve esa información'''
df_coordenadas = pd.read_csv('.\data\df_coordenadas.csv', index_col= 'Unnamed: 0')

# %%
df = f.rellenar_columnas_F(df)
df = f.rellenar_annios_nulos_necesitan_reforma(df)
df = f.rellenar_annios_nulos_no_necesitan_reforma(df)
df = f.rellenar_pisos_nulos(df)
df = f.rellenar_bajos_nulos(df)
df = f.sacar_metros_cuadrados_nuevos(df)
df = f.rellenar_exterior(df)
df = f.rellenar_tipo_inmueble(df)
df = f.rellenar_bannos_nulos(df)
df = f.determinacion_zonas(df)
df = pd.merge(df,df_coordenadas, on= 'ubicacion')

df.head()
# Out:
#    precio_venta  precio_venta_por_m2         cee  balcon  armarios_empotrados  \
# 0         85000                 1328           D   False                False
# 1         72000                 1125           F   False                False
# 2         76000                 1188  en trámite   False                False
# 3        110000                 1719           E   False                False
# 4         94000                 1446  en trámite   False                 True
#
#    jardin  zonas_verdes  estacionamiento  pileta  trastero  terraza  \
# 0   False         False            False   False     False    False
# 1   False         False            False   False     False     True
# 2   False         False            False   False     False    False
# 3   False         False            False   False     False     True
# 4   False         False            False   False     False     True
#
#         tipo_inmueble  accesible  exterior   bajo  necesita_reforma  \
# 0  HouseType 1: Pisos      False     False  False             False
# 1  HouseType 1: Pisos      False     False  False             False
# 2  HouseType 1: Pisos      False     False  False              True
# 3  HouseType 1: Pisos      False     False  False             False
# 4  HouseType 1: Pisos      False     False  False             False
#
#    habitaciones              ubicacion  annio_construccion piso  \
# 0             2  San Cristóbal, Madrid              1960.0    3
# 1             3  San Cristóbal, Madrid              1960.0    3
# 2             3  San Cristóbal, Madrid              1960.0    1
# 3             2  San Cristóbal, Madrid              1968.0    2
# 4             3  San Cristóbal, Madrid              1968.0    1
#
#    metros_cuadrados  bannos zona    latitud  longitud
# 0              64.0     1.0  sur  40.343354 -3.687817
# 1              64.0     1.0  sur  40.343354 -3.687817
# 2              64.0     1.0  sur  40.343354 -3.687817
# 3              64.0     1.0  sur  40.343354 -3.687817
# 4              65.0     1.0  sur  40.343354 -3.687817

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   precio_venta         21742 non-null  int64
#  1   precio_venta_por_m2  21742 non-null  int64
#  2   cee                  21742 non-null  object
#  3   balcon               21742 non-null  bool
#  4   armarios_empotrados  21742 non-null  bool
#  5   jardin               21742 non-null  bool
#  6   zonas_verdes         21742 non-null  bool
#  7   estacionamiento      21742 non-null  bool
#  8   pileta               21742 non-null  bool
#  9   trastero             21742 non-null  bool
#  10  terraza              21742 non-null  bool
#  11  tipo_inmueble        21742 non-null  object
#  12  accesible            21742 non-null  bool
#  13  exterior             21742 non-null  bool
#  14  bajo                 21742 non-null  bool
#  15  necesita_reforma     21742 non-null  bool
#  16  habitaciones         21742 non-null  int64
#  17  ubicacion            21742 non-null  object
#  18  annio_construccion   21742 non-null  float64
#  19  piso                 21742 non-null  object
#  20  metros_cuadrados     21742 non-null  float64
#  21  bannos               21742 non-null  float64
#  22  zona                 21742 non-null  object
#  23  latitud              21742 non-null  float64
#  24  longitud             21742 non-null  float64
# dtypes: bool(12), float64(5), int64(3), object(5)
# memory usage: 2.4+ MB

# %%
f.grafico_variable_ppal(df)
# Out:
# d:\Documentos\2.CURSOS\BOOTCAMP\EDA_Viviendas_Madrid\src\utils\funciones.py:320: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=data, x='precio_venta_por_m2',fill=True,palette='hls')
# kurtosis: 2.15
# simetria: 1.17
# La distribución es leptocúrtica, lo que sugiere colas pesadas y picos agudos.
# La distribución es asimétrica negativa (sesgo hacia la izquierda).

# %%
f.prueba_grafica_normalidad(df)

# %%
f.prueba_normalidad_shapiro(df)
# Out:
# Estadística de prueba: 0.9275674819946289
# Valor p: 0.0
# Rechazamos la hipótesis nula; los datos no siguen una distribución normal.
# c:\Users\Mega Tecnologia\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
f.pair_plot(df)
# Out:
# c:\Users\Mega Tecnologia\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Mega Tecnologia\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Mega Tecnologia\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Mega Tecnologia\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Mega Tecnologia\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)

# %%
f.precio_cee(df)
# Out:
# No pude hacer el gráfico por The number of FixedLocator locations (6), usually from a call to set_ticks, does not match the number of ticklabels (10).

# %%
f.precio_tipo_inmueble(df)

# %%
f.grafico_precio_zona_yvariable(df,'estacionamiento')

# %%
f.grafico_precio_habitaciones_yvariable(df,'estacionamiento')

# %%
df_num = f.tranformacion_numerica(df)
